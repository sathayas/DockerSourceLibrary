# %% [markdown]
# # Plotting test
#
# ***
#
# Running `matplotlib.pyplot` to see if it can be seen from outside of the container.

# %%
# %matplotlib inline

# %% [markdown]
# This line is needed to produce

# %%
import matplotlib.pyplot as plt 
plt.plot([0,1,2,5],[0,1,4,25]) 
plt.title('Some plot')
plt.show()
